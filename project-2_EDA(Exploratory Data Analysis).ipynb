# %%
import pandas as pd
var = pd.read_csv("cleaned_dataset.csv")

# %%
var
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex      Age  SibSp  \
# 0                                Kelly, Mr. James    male     34.5      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female     47.0      1
# 2                       Myles, Mr. Thomas Francis    male     62.0      0
# 3                                Wirz, Mr. Albert    male     27.0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female     22.0      1
# ..                                            ...     ...      ...    ...
# ...

# %%
#Dataset Information
var.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex      Age  SibSp  \
# 0                                Kelly, Mr. James    male     34.5      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female     47.0      1
# 2                       Myles, Mr. Thomas Francis    male     62.0      0
# 3                                Wirz, Mr. Albert    male     27.0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female     22.0      1
# ...

# %%
#Basics Statistics:count,mean,standard deviation,min,max
var.describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch
# count   418.000000  418.000000  418.000000  418.000000  418.000000
# mean   1100.500000    0.363636    2.265550    0.447368    0.392344
# std     120.810458    0.481622    0.841838    0.896760    0.981429
# min     892.000000    0.000000    1.000000    0.000000    0.000000
# 25%     996.250000    0.000000    1.000000    0.000000    0.000000
# 50%    1100.500000    0.000000    3.000000    0.000000    0.000000
# 75%    1204.750000    1.000000    3.000000    1.000000    0.000000
# max    1309.000000    1.000000    3.000000    8.000000    9.000000

# %%
#Survival Analysis
var['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
#Count Passenger Classes
var['Pclass'].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
var['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
var['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
var['Age'].hist()
# Out:
# <Axes: >

# %%
var['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# # Observations
#
# 1. The majority of passengers were male.
# 2. Most passengers belonged to the 3rd class.
# 3. The number of passengers who did not survive was higher than those who survived.
# 4. The average passenger age was around 30.27 years.
# 5. The dataset was cleaned before analysis by handling missing values and duplicates.
